# %%
principal = int(input("元金を入力してください: "))

rate = float(input("年利を入力してください: "))

rate = rate / 100

amount = principal
for year in range(10):
    amount = amount * (1 + rate)

print("10年後の金額:", round(amount, 2))
# Out:
# 10年後の金額: 1628.89
